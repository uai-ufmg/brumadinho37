# %%
import pandas as pd
import numpy as np

# %%
def ler_pop(ano):

    df = pd.read_csv(f"bases_socio/pop{ano}.csv", sep=';', encoding='latin')
    
    df.drop(df.tail(1).index,inplace=True)
    
    df['id_municipio'] = df['Município'].str[:6] #coluna do codigo do municipio
    df['id_municipio'] = df['id_municipio'].astype('int64')
    df['Município'] = df['Município'].str[7:] #coluna do nome do municipio
    
    df.columns = ['Município', f'pop{ano}Masc', f'pop{ano}Fem', f'pop{ano}Total', 'id_municipio']
    
    return df

def merge_pop(pop, pop2):
    pop = pop.merge(pop2, how="right")
    return pop

pop2010 = ler_pop(2010)

"""
pop2011 = ler_pop(2011)
pop2012 = ler_pop(2012)
pop2013 = ler_pop(2013)
pop2014 = ler_pop(2014)
pop2015 = ler_pop(2015)
pop2016 = ler_pop(2016)
pop2017 = ler_pop(2017)
pop2018 = ler_pop(2018)
pop2019 = ler_pop(2019)

pop = merge_pop(pop2010, pop2011)
pop = merge_pop(pop, pop2012)
pop = merge_pop(pop, pop2013)
pop = merge_pop(pop, pop2014)
pop = merge_pop(pop, pop2015)
pop = merge_pop(pop, pop2016)
pop = merge_pop(pop, pop2017)
pop = merge_pop(pop, pop2018)
pop = merge_pop(pop, pop2019)
pop

"""
# Out:
# '\npop2011 = ler_pop(2011)\npop2012 = ler_pop(2012)\npop2013 = ler_pop(2013)\npop2014 = ler_pop(2014)\npop2015 = ler_pop(2015)\npop2016 = ler_pop(2016)\npop2017 = ler_pop(2017)\npop2018 = ler_pop(2018)\npop2019 = ler_pop(2019)\n\npop = merge_pop(pop2010, pop2011)\npop = merge_pop(pop, pop2012)\npop = merge_pop(pop, pop2013)\npop = merge_pop(pop, pop2014)\npop = merge_pop(pop, pop2015)\npop = merge_pop(pop, pop2016)\npop = merge_pop(pop, pop2017)\npop = merge_pop(pop, pop2018)\npop = merge_pop(pop, pop2019)\npop\n\n'

# %%
#grupos de cidades analisadas
cidades_selecionadas = ["Betim", 'Brumadinho','Curvelo','Esmeraldas','Florestal','Fortuna de Minas',
                        'Igarapé','Juatuba','Maravilhas','Mário Campos','Martinho Campos',
                        'Papagaios','Pará de Minas','Paraopeba','Pequi','Pompéu','São Joaquim de Bicas',
                        'São José da Varginha','Sarzedo']

cidades_limitrofes = ['Abaeté','Araçaí','Belo Horizonte','Belo Vale','Bom Despacho','Bonfim','Cachoeira da Prata',
                      'Caetanópolis','Capim Branco','Conceição do Pará','Contagem','Cordisburgo','Corinto',
                      'Dores do Indaiá','Felixlândia','Ibirité','Igaratinga','Inhaúma','Inimutaba','Itaúna',
                      'Itabirito','Itatiaiuçu','Leandro Ferreira','Mateus Leme','Matozinhos','Moeda',
                      'Morada Nova de Minas','Morro da Garça','Nova Lima','Onça de Pitangui','Paineiras',
                      'Pedro Leopoldo','Pitangui','Presidente Juscelino','Quartel Geral','Ribeirão das Neves',
                      'Rio Manso','Santana de Pirapama','Santo Hipólito','Sete Lagoas']


cidades_prox_limitrofes = ['Araújos','Augusto de Lima','Baldim','Biquinhas','Carmo do Cajuru','Cedro do Abaeté',
                           'Conceição do Mato Dentro','Confins','Congonhas','Congonhas do Norte','Crucilândia',
                           'Estrela do Indaiá','Funilândia','Gouveia','Itaguara','Jaboticatubas','Jeceaba',
                           'Jequitibá','Lagoa Santa','Lassance','Luz','Moema','Monjolos','Nova Serrana',
                           'Ouro Preto','Piedade dos Gerais','Prudente de Morais',
                           'Raposos','Rio Acima','Sabará','São Gonçalo do Abaeté','São Gonçalo do Pará',
                           'São Gotardo','São José da Lapa','Santa Bárbara','Santa Luzia','Santana do Riacho',
                           'Santo Antônio do Monte','Serra da Saudade','Tiros','Vespasiano']


#gera uma lista com o ID de todas as cidades a serem avaliadas
todas = cidades_selecionadas + cidades_limitrofes + cidades_prox_limitrofes

# %%
nome1 = "Escolaridade - Taxa de analfabetismo da população de 15 anos ou mais"
nome2 = "Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede)"
nome3 = "Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta)"
nome4 = "Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede)"
nome5 = "Saneamento - Percentual de pessoas em situação de vulnerabilidade pelas condições de saneamento básico"
nome6 = "Trabalho e renda - Percentual da população pobre ou extremamente pobre no Cadastro Único em relação a população total do município"
nome7 = "Trabalho e renda - Produto Interno Bruto per capita"
nome8 = "Trabalho e renda - Salário médio mensal dos trabalhadores formais (salário mínimo) 2019"
nome9 = "Trabalho e renda - Taxa de emprego no setor formal"

nome10 = "educacao_escolaridade15+_f"
nome11 = "educacao_escolaridade15+_m"
nome12 = "educacao_escolaridade15+_t"
nome13 = "gini_idhm_atlas"
nome14 = "trabalhorenda_propbaixarenda__1-2SM"
nome15 = "trabalhorenda_propbaixarenda__1-4SM"
nome16 = "trabalhorenda_propcriancabaixarenda__1-2SM"
nome17 = "trabalhorenda_propcriancabaixarenda__1-4SM"
nome18 = "trabalhorenda_razao"
nome19 = "trabalhorenda_txdesemprego"

# %%
# 1-7, 9 -> normal
# 8 -> encoding
# 10-12, 14-19 -> código + município
# 13 -> vírgula, encoding, "Territorialidades"

# %%
def ler_base(nome, encoding=True, sep=";"):
    if encoding:
        df = pd.read_csv(f"bases_socio/{nome}.csv", sep=sep, encoding='latin')
    else:
        df = pd.read_csv(f"bases_socio/{nome}.csv", sep=sep)
        
    return df

def tratar_base(nome, encoding=True, sep=";"):
    df = ler_base(nome, encoding = encoding, sep = sep)
    
    novas_colunas = []
    for i in df.columns:
        if i.isnumeric():
            df[i] = df[i].str.replace(",", ".").astype('float32')
            novas_colunas.append(f"{nome} - {i}")
        else:
            novas_colunas.append(i)
    
    df.columns = novas_colunas
    
    return df

def tratar_base_jp(nome, encoding=True, sep=";"):
    df = ler_base(nome, encoding = encoding, sep = sep)
    
    novas_colunas = []
    for i in df.columns:
        if i.isnumeric():
            df[i] = df[i].str.replace(",", ".").astype('float32')
            novas_colunas.append(f"{nome} - {i}")
        else:
            novas_colunas.append(i)
    
    df.columns = novas_colunas
    
    df['id_municipio'] = df['Município'].str[:6].astype('int64') #coluna do codigo do municipio
    df['Município'] = df['Município'].str[7:] #coluna do nome do municipio
    
    #df.drop('Município', axis=1, inplace=True)
    
    #df = df[df['municipio'].isin(todas)]
    
    return df

# %%
def substituir_nomes_errados(df):
    idx1 = df[df["Município"] == "Leandro ferreira"].index[0]
    idx2 = df[df["Município"] == "Onça do Pitangui"].index[0]
    df.loc[idx1, "Município"] = "Leandro Ferreira"
    df.loc[idx2, "Município"] = "Onça de Pitangui"
    return df

# %%
df1 = substituir_nomes_errados(tratar_base(nome1))
df2 = substituir_nomes_errados(tratar_base(nome2))
df3 = substituir_nomes_errados(tratar_base(nome3))
df4 = substituir_nomes_errados(tratar_base(nome4))
df5 = substituir_nomes_errados(tratar_base(nome5))
df6 = substituir_nomes_errados(tratar_base(nome6))
df7 = substituir_nomes_errados(tratar_base(nome7))
df8 = tratar_base(nome8, False)
df8[" Salário médio mensal dos trabalhadores formais"] = df8[" Salário médio mensal dos trabalhadores formais"].str.replace(",", ".").astype('float32')
df8.columns = ["Município", "Salário médio mensal dos trabalhadores formais"]
df9 = substituir_nomes_errados(tratar_base(nome9))

df10 = tratar_base_jp(nome10)
df11 = tratar_base_jp(nome11)
df12 = tratar_base_jp(nome12)
df13 = tratar_base(nome13, sep=",", encoding = False)
df13.columns = ['Município', 'Índice de Gini 2010', 'IDHM 2010']
df14 = tratar_base_jp(nome14)
df15 = tratar_base_jp(nome15)
df16 = tratar_base_jp(nome16)
df17 = tratar_base_jp(nome17)
df18 = tratar_base_jp(nome18)
df19 = tratar_base_jp(nome19)

# %%
tratar_base(nome13, sep=",", encoding = False)
# Out:
#           Territorialidades  Índice de Gini 2010  IDHM 2010
# 0       Abadia dos Dourados                 0.47      0.689
# 1                    Abaeté                 0.54      0.698
# 2                Abre Campo                 0.52      0.654
# 3                   Acaiaca                 0.48      0.630
# 4                   Açucena                 0.48      0.610
# ..                      ...                  ...        ...
# 847            Virginópolis                 0.49      0.675
# 848             Virgolândia                 0.51      0.620
# 849  Visconde do Rio Branco                 0.49      0.709
# 850            Volta Grande                 0.51      0.669
# 851          Wenceslau Braz                 0.44      0.678
#
# [852 rows x 3 columns]

# %%
df_final = df1.merge(df2, how="right")
df_final = df_final.merge(df3, how="right")
df_final = df_final.merge(df3, how="right")
df_final = df_final.merge(df4, how="right")
df_final = df_final.merge(df5, how="right")
df_final = df_final.merge(df6, how="right")
df_final = df_final.merge(df7, how="right")
df_final = df_final.merge(df8, how="right")
df_final = df_final.merge(df9, how="right")
df_final = df_final.merge(df9, how="right")
df_final = df_final.merge(df10, how="right")
df_final = df_final.merge(df11, how="right")
df_final = df_final.merge(df12, how="right")
df_final = df_final.merge(df13, how="right")
df_final = df_final.merge(df14, how="right")
df_final = df_final.merge(df15, how="right")
df_final = df_final.merge(df16, how="right")
df_final = df_final.merge(df17, how="right")
df_final = df_final.merge(df18, how="right")
df_final = df_final.merge(df19, how="right")

df_final = df_final.merge(pop2010, how="right")

df_final = df_final[df_final['Município'].isin(todas)]


df_final
# Out:
#          ibge7         Município  \
# 1    3100203.0            Abaeté
# 34   3103207.0            Araçaí
# 42   3103900.0           Araújos
# 52   3104809.0   Augusto de Lima
# 54   3105004.0            Baldim
# ..         ...               ...
# 769  3165537.0           Sarzedo
# 782  3166600.0  Serra da Saudade
# 789  3167202.0       Sete Lagoas
# 808  3168903.0             Tiros
# 843  3171204.0        Vespasiano
#
#      Escolaridade - Taxa de analfabetismo da população de 15 anos ou mais - 2010  \
# 1                                                 8.72
# 34                                               10.29
# 42                                                8.10
# 52                                               14.47
# 54                                                9.32
# ..                                                 ...
# 769                                               5.88
# 782                                              13.46
# ...

# %%
df_final.columns = ['ibge7', 'municipio',
       'Escolaridade - Taxa de analfabetismo da população de 15 anos ou mais - 2010',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2010',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2011',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2012',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2013',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2014',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2015',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2016',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2017',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2018',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2010',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2011',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2012',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2013',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2014',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2015',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2016',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2017',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2018',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2010',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2011',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2012',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2013',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2014',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2015',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2016',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2017',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2018',
       'Saneamento - Percentual de pessoas em situação de vulnerabilidade pelas condições de saneamento básico - 2014',
       'Saneamento - Percentual de pessoas em situação de vulnerabilidade pelas condições de saneamento básico - 2015',
       'Saneamento - Percentual de pessoas em situação de vulnerabilidade pelas condições de saneamento básico - 2016',
       'Saneamento - Percentual de pessoas em situação de vulnerabilidade pelas condições de saneamento básico - 2017',
       'Saneamento - Percentual de pessoas em situação de vulnerabilidade pelas condições de saneamento básico - 2018',
       'Saneamento - Percentual de pessoas em situação de vulnerabilidade pelas condições de saneamento básico - 2019',
       'Trabalho e renda - Percentual da população pobre ou extremamente pobre no Cadastro Único em relação a população total do município - 2014',
       'Trabalho e renda - Percentual da população pobre ou extremamente pobre no Cadastro Único em relação a população total do município - 2015',
       'Trabalho e renda - Percentual da população pobre ou extremamente pobre no Cadastro Único em relação a população total do município - 2016',
       'Trabalho e renda - Percentual da população pobre ou extremamente pobre no Cadastro Único em relação a população total do município - 2017',
       'Trabalho e renda - Percentual da população pobre ou extremamente pobre no Cadastro Único em relação a população total do município - 2018',
       'Trabalho e renda - Percentual da população pobre ou extremamente pobre no Cadastro Único em relação a população total do município - 2019',
       'Trabalho e renda - Produto Interno Bruto per capita - 2010',
       'Trabalho e renda - Produto Interno Bruto per capita - 2011',
       'Trabalho e renda - Produto Interno Bruto per capita - 2012',
       'Trabalho e renda - Produto Interno Bruto per capita - 2013',
       'Trabalho e renda - Produto Interno Bruto per capita - 2014',
       'Trabalho e renda - Produto Interno Bruto per capita - 2015',
       'Trabalho e renda - Produto Interno Bruto per capita - 2016',
       'Trabalho e renda - Produto Interno Bruto per capita - 2017',
       'Trabalho e renda - Produto Interno Bruto per capita - 2018',
       'Salário médio mensal dos trabalhadores formais',
       'Trabalho e renda - Taxa de emprego no setor formal - 2010',
       'Trabalho e renda - Taxa de emprego no setor formal - 2011',
       'Trabalho e renda - Taxa de emprego no setor formal - 2012',
       'Trabalho e renda - Taxa de emprego no setor formal - 2013',
       'Trabalho e renda - Taxa de emprego no setor formal - 2014',
       'Trabalho e renda - Taxa de emprego no setor formal - 2015',
       'Trabalho e renda - Taxa de emprego no setor formal - 2016',
       'Trabalho e renda - Taxa de emprego no setor formal - 2017',
       'Trabalho e renda - Taxa de emprego no setor formal - 2018',
       'Trabalho e renda - Taxa de emprego no setor formal - 2019',
       'educacao_escolaridade15+_f - Sem instrução/1º ciclo fundamental incompleto - Mulheres',
       'educacao_escolaridade15+_f - 1º ciclo fundamental completo/2º ciclo incompleto - Mulheres',
       'educacao_escolaridade15+_f - 2º ciclo fundamental completo ou mais', 'educacao_escolaridade15+_f - Não determinada - Mulheres',
       'educacao_escolaridade15+_f - Todos os Ciclos - Mulheres', 'id_municipio',
       'educacao_escolaridade15+_m - Sem instrução/1º ciclo fundamental incompleto - Homens',
       'educacao_escolaridade15+_m - 1º ciclo fundamental completo/2º ciclo incompleto - Homens',
       'educacao_escolaridade15+_m - 2º ciclo fundamental completo ou mais - Homens',
       'educacao_escolaridade15+_m - Não determinada - Homens', 'educacao_escolaridade15+_m - Todos os Ciclos - Homens',
       'educacao_escolaridade15+_t - Sem instrução/1º ciclo fundamental incompleto - Total',
       'educacao_escolaridade15+_t - 1º ciclo fundamental completo/2º ciclo incompleto - Total',
       'educacao_escolaridade15+_t - 2º ciclo fundamental completo ou mais - Total',
       'educacao_escolaridade15+_t - Não determinada - Total', 'educacao_escolaridade15+_t - Todos os Ciclos - Total',
       'Índice de Gini 2010', 'IDHM 2010', '%_população_com_renda_<_1/2_SM',
       '%_população_com_renda_<_1/4_SM', '%_crianças_renda_dom_<_1/2_SM',
       '%_crianças_renda_dom_<_1/4_SM', 'razaorenda - 1991',
       'razaorenda - 2000', 'razaorenda - 2010', 'Taxa_de_desemprego_16a_e+', 'pop2010Masc', 'pop2010Fem', 'pop2010Total']

# %%
df_final = df_final.drop(columns=['ibge7'])
df_final.columns
# Out:
# Index(['municipio',
#        'Escolaridade - Taxa de analfabetismo da população de 15 anos ou mais - 2010',
#        'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2010',
#        'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2011',
#        'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2012',
#        'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2013',
#        'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2014',
#        'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2015',
#        'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2016',
#        'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2017',
# ...

# %%
df = df_final[['id_municipio', 'municipio', 'pop2010Masc', 'pop2010Fem', 'pop2010Total',
       'Escolaridade - Taxa de analfabetismo da população de 15 anos ou mais - 2010',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2010',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2011',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2012',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2013',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2014',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2015',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2016',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2017',
       'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2018',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2010',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2011',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2012',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2013',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2014',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2015',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2016',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2017',
       'Saneamento - Percentual da população urbana em domicílios com coleta de lixo (direta e indireta) - 2018',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2010',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2011',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2012',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2013',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2014',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2015',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2016',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2017',
       'Saneamento - Percentual da população urbana em domicílios com esgotamento sanitário (rede) - 2018',
       'Saneamento - Percentual de pessoas em situação de vulnerabilidade pelas condições de saneamento básico - 2014',
       'Saneamento - Percentual de pessoas em situação de vulnerabilidade pelas condições de saneamento básico - 2015',
       'Saneamento - Percentual de pessoas em situação de vulnerabilidade pelas condições de saneamento básico - 2016',
       'Saneamento - Percentual de pessoas em situação de vulnerabilidade pelas condições de saneamento básico - 2017',
       'Saneamento - Percentual de pessoas em situação de vulnerabilidade pelas condições de saneamento básico - 2018',
       'Saneamento - Percentual de pessoas em situação de vulnerabilidade pelas condições de saneamento básico - 2019',
       'Trabalho e renda - Percentual da população pobre ou extremamente pobre no Cadastro Único em relação a população total do município - 2014',
       'Trabalho e renda - Percentual da população pobre ou extremamente pobre no Cadastro Único em relação a população total do município - 2015',
       'Trabalho e renda - Percentual da população pobre ou extremamente pobre no Cadastro Único em relação a população total do município - 2016',
       'Trabalho e renda - Percentual da população pobre ou extremamente pobre no Cadastro Único em relação a população total do município - 2017',
       'Trabalho e renda - Percentual da população pobre ou extremamente pobre no Cadastro Único em relação a população total do município - 2018',
       'Trabalho e renda - Percentual da população pobre ou extremamente pobre no Cadastro Único em relação a população total do município - 2019',
       'Trabalho e renda - Produto Interno Bruto per capita - 2010',
       'Trabalho e renda - Produto Interno Bruto per capita - 2011',
       'Trabalho e renda - Produto Interno Bruto per capita - 2012',
       'Trabalho e renda - Produto Interno Bruto per capita - 2013',
       'Trabalho e renda - Produto Interno Bruto per capita - 2014',
       'Trabalho e renda - Produto Interno Bruto per capita - 2015',
       'Trabalho e renda - Produto Interno Bruto per capita - 2016',
       'Trabalho e renda - Produto Interno Bruto per capita - 2017',
       'Trabalho e renda - Produto Interno Bruto per capita - 2018',
       'Salário médio mensal dos trabalhadores formais',
       'Trabalho e renda - Taxa de emprego no setor formal - 2010',
       'Trabalho e renda - Taxa de emprego no setor formal - 2011',
       'Trabalho e renda - Taxa de emprego no setor formal - 2012',
       'Trabalho e renda - Taxa de emprego no setor formal - 2013',
       'Trabalho e renda - Taxa de emprego no setor formal - 2014',
       'Trabalho e renda - Taxa de emprego no setor formal - 2015',
       'Trabalho e renda - Taxa de emprego no setor formal - 2016',
       'Trabalho e renda - Taxa de emprego no setor formal - 2017',
       'Trabalho e renda - Taxa de emprego no setor formal - 2018',
       'Trabalho e renda - Taxa de emprego no setor formal - 2019',
       'educacao_escolaridade15+_f - Sem instrução/1º ciclo fundamental incompleto - Mulheres',
       'educacao_escolaridade15+_f - 1º ciclo fundamental completo/2º ciclo incompleto - Mulheres',
       'educacao_escolaridade15+_f - 2º ciclo fundamental completo ou mais',
       'educacao_escolaridade15+_f - Não determinada - Mulheres',
       'educacao_escolaridade15+_f - Todos os Ciclos - Mulheres',
       'educacao_escolaridade15+_m - Sem instrução/1º ciclo fundamental incompleto - Homens',
       'educacao_escolaridade15+_m - 1º ciclo fundamental completo/2º ciclo incompleto - Homens',
       'educacao_escolaridade15+_m - 2º ciclo fundamental completo ou mais - Homens',
       'educacao_escolaridade15+_m - Não determinada - Homens',
       'educacao_escolaridade15+_m - Todos os Ciclos - Homens',
       'educacao_escolaridade15+_t - Sem instrução/1º ciclo fundamental incompleto - Total',
       'educacao_escolaridade15+_t - 1º ciclo fundamental completo/2º ciclo incompleto - Total',
       'educacao_escolaridade15+_t - 2º ciclo fundamental completo ou mais - Total',
       'educacao_escolaridade15+_t - Não determinada - Total',
       'educacao_escolaridade15+_t - Todos os Ciclos - Total',
       'Índice de Gini 2010', 'IDHM 2010', '%_população_com_renda_<_1/2_SM',
       '%_população_com_renda_<_1/4_SM', '%_crianças_renda_dom_<_1/2_SM',
       '%_crianças_renda_dom_<_1/4_SM', 'razaorenda - 1991',
       'razaorenda - 2000', 'razaorenda - 2010', 'Taxa_de_desemprego_16a_e+']]

# %%
df["%_população_com_renda_<_1/2_SM"] = df["%_população_com_renda_<_1/2_SM"].str.replace(",", ".")
df["%_população_com_renda_<_1/4_SM"] = df["%_população_com_renda_<_1/4_SM"].str.replace(",", ".")
df["%_crianças_renda_dom_<_1/2_SM"] = df["%_crianças_renda_dom_<_1/2_SM"].str.replace(",", ".")
df["%_crianças_renda_dom_<_1/4_SM"] = df["%_crianças_renda_dom_<_1/4_SM"].str.replace(",", ".")
df["razaorenda - 1991"] = df["razaorenda - 1991"].str.replace(",", ".")
df["razaorenda - 2000"] = df["razaorenda - 2000"].str.replace(",", ".")
df["razaorenda - 2010"] = df["razaorenda - 2010"].str.replace(",", ".")
df["Taxa_de_desemprego_16a_e+"] = df["Taxa_de_desemprego_16a_e+"].str.replace(",", ".")

df["%_população_com_renda_<_1/2_SM"] = pd.to_numeric(df["%_população_com_renda_<_1/2_SM"], errors='coerce')
df["%_população_com_renda_<_1/4_SM"] = pd.to_numeric(df["%_população_com_renda_<_1/4_SM"], errors='coerce')
df["%_crianças_renda_dom_<_1/2_SM"] = pd.to_numeric(df["%_crianças_renda_dom_<_1/2_SM"], errors='coerce')
df["%_crianças_renda_dom_<_1/4_SM"] = pd.to_numeric(df["%_crianças_renda_dom_<_1/4_SM"], errors='coerce')
df["razaorenda - 1991"] = pd.to_numeric(df["razaorenda - 1991"], errors='coerce')
df["razaorenda - 2000"] = pd.to_numeric(df["razaorenda - 2000"], errors='coerce')
df["razaorenda - 2010"] = pd.to_numeric(df["razaorenda - 2010"], errors='coerce')
df["Taxa_de_desemprego_16a_e+"] = pd.to_numeric(df["Taxa_de_desemprego_16a_e+"], errors='coerce')

# %%
df[df['Trabalho e renda - Taxa de emprego no setor formal - 2018'] > 100]
# Out:
#      id_municipio municipio  pop2010Masc  pop2010Fem  pop2010Total  \
# 197      311787.0   Confins         2248        2411          4659
# 401      313540.0   Jeceaba         2195        2154          4349
#
#      Escolaridade - Taxa de analfabetismo da população de 15 anos ou mais - 2010  \
# 197                                               4.92
# 401                                               8.07
#
#      Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2010  \
# 197                                              100.0
# 401                                              100.0
#
#      Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2011  \
# 197                                              100.0
# 401                                               84.5
#
#      Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2012  \
# ...

# %%
df[df["Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2010"].isnull() == True]
# Out:
#      id_municipio            municipio  pop2010Masc  pop2010Fem  pop2010Total  \
# 42       310390.0              Araújos         3101        3014          6115
# 352      313100.0              Inhaúma         2242        2224          4466
# 434      313810.0             Lassance         2444        2303          4747
# 489      314240.0                Moema         2822        2757          5579
# 579      314960.0                Pequi         1603        1633          3236
# 624      315360.0   Prudente de Morais         3547        3835          7382
# 638      315480.0            Rio Acima         3492        3634          7126
# 689      315850.0  Santana de Pirapama         3252        3015          6267
#
#      Escolaridade - Taxa de analfabetismo da população de 15 anos ou mais - 2010  \
# 42                                                8.10
# 352                                               8.65
# 434                                              15.06
# ...

# %%
df
# Out:
#      id_municipio         municipio  pop2010Masc  pop2010Fem  pop2010Total  \
# 1        310020.0            Abaeté         8922        9245         18167
# 34       310320.0            Araçaí          828         913          1741
# 42       310390.0           Araújos         3101        3014          6115
# 52       310480.0   Augusto de Lima         1899        1855          3754
# 54       310500.0            Baldim         3026        3172          6198
# ..            ...               ...          ...         ...           ...
# 769      316553.0           Sarzedo         9470        9692         19162
# 782      316660.0  Serra da Saudade          340         301           641
# 789      316720.0       Sete Lagoas        81593       88751        170344
# 808      316890.0             Tiros         2913        2699          5612
# 843      317120.0        Vespasiano        37642       40860         78502
#
# ...

# %%
df.to_csv("dados_socieconomicos2.csv", encoding='latin1')

# %%
df
# Out:
#      id_municipio         municipio  pop2010Masc  pop2010Fem  pop2010Total  \
# 1        310020.0            Abaeté         8922        9245         18167
# 34       310320.0            Araçaí          828         913          1741
# 42       310390.0           Araújos         3101        3014          6115
# 52       310480.0   Augusto de Lima         1899        1855          3754
# 54       310500.0            Baldim         3026        3172          6198
# ..            ...               ...          ...         ...           ...
# 769      316553.0           Sarzedo         9470        9692         19162
# 782      316660.0  Serra da Saudade          340         301           641
# 789      316720.0       Sete Lagoas        81593       88751        170344
# 808      316890.0             Tiros         2913        2699          5612
# 843      317120.0        Vespasiano        37642       40860         78502
#
# ...

# %%
colunas = df.columns[5:]
colunas
# Out:
# Index(['Escolaridade - Taxa de analfabetismo da população de 15 anos ou mais - 2010',
#        'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2010',
#        'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2011',
#        'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2012',
#        'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2013',
#        'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2014',
#        'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2015',
#        'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2016',
#        'Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2017',
# ...

# %%
for col in colunas:
    print(df[col].isnull().any)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.any of 1      False
# 34     False
# 42     False
# 52     False
# 54     False
#        ...
# 769    False
# 782    False
# 789    False
# 808    False
# 843    False
# Name: Escolaridade - Taxa de analfabetismo da população de 15 anos ou mais - 2010, Length: 100, dtype: bool>
# <bound method NDFrame._add_numeric_operations.<locals>.any of 1      False
# 34     False
# 42      True
# 52     False
# 54     False
#        ...
# 769    False
# 782    False
# 789    False
# 808    False
# 843    False
# Name: Saneamento - Percentual da população urbana em domicílios com abastecimento de água (rede) - 2010, Length: 100, dtype: bool>
# <bound method NDFrame._add_numeric_operations.<locals>.any of 1      False
# 34     False
# 42      True
# 52     False
# 54     False
#        ...
# 769    False
# 782    False
# 789    False
# 808    False
# 843    False
# ...

# %%
rows_with_nan = []
for index, row in df.iterrows():
    print(row["municipio"])
    soma = 0
    for col in row:
        if (pd.isnull(col)):
            soma += 1
    print(f"Missings = {soma}")
    print()
# Out:
# Abaeté
# Missings = 14
#
# Araçaí
# Missings = 5
#
# Araújos
# Missings = 18
#
# Augusto de Lima
# Missings = 18
#
# Baldim
# Missings = 4
#
# Belo Horizonte
# Missings = 0
#
# Belo Vale
# Missings = 6
#
# Betim
# Missings = 0
#
# Biquinhas
# Missings = 13
#
# Bom Despacho
# Missings = 3
#
# Bonfim
# Missings = 1
#
# Brumadinho
# Missings = 1
#
# Cachoeira da Prata
# Missings = 7
#
# Caetanópolis
# Missings = 10
#
# Capim Branco
# Missings = 3
#
# Carmo do Cajuru
# Missings = 2
#
# Cedro do Abaeté
# Missings = 8
#
# Conceição do Mato Dentro
# Missings = 3
#
# Conceição do Pará
# Missings = 5
#
# Confins
# Missings = 16
#
# Congonhas
# Missings = 3
#
# Congonhas do Norte
# Missings = 2
#
# Contagem
# Missings = 0
#
# Cordisburgo
# Missings = 0
#
# Corinto
# Missings = 3
#
# Crucilândia
# Missings = 6
#
# Curvelo
# Missings = 0
#
# Dores do Indaiá
# Missings = 3
#
# Esmeraldas
# Missings = 6
#
# Estrela do Indaiá
# Missings = 6
#
# Felixlândia
# Missings = 11
#
# Florestal
# ...
