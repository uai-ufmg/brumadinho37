# %%
import pandas as pd
import numpy as np

df = pd.read_csv("pre_taxa_sim_cap.csv")
df
# Out:
#           municipio  id_municipio   ano faixa_etaria  pop_total  \
# 0            Abaeté        310020  2010          0a4       1377
# 1            Abaeté        310020  2010          0a4       1377
# 2            Abaeté        310020  2010          0a4       1377
# 3            Abaeté        310020  2010          0a4       1377
# 4            Abaeté        310020  2010          0a4       1377
# ...             ...           ...   ...          ...        ...
# 1835995  Vespasiano        317120  2019     >=80anos       1507
# 1835996  Vespasiano        317120  2019     >=80anos       1507
# 1835997  Vespasiano        317120  2019     >=80anos       1507
# 1835998  Vespasiano        317120  2019     >=80anos       1507
# 1835999  Vespasiano        317120  2019     >=80anos       1507
#
#          pop_pad_total  pop_homem  pop_pad_homem  pop_mulher  pop_pad_mulher  \
# 0              1338553        702         684629         675          653924
# 1              1338553        702         684629         675          653924
# 2              1338553        702         684629         675          653924
# 3              1338553        702         684629         675          653924
# 4              1338553        702         684629         675          653924
# ...                ...        ...            ...         ...             ...
# 1835995         334532        528         129431         979          205101
# 1835996         334532        528         129431         979          205101
# 1835997         334532        528         129431         979          205101
# 1835998         334532        528         129431         979          205101
# 1835999         334532        528         129431         979          205101
#
#          ...  taxa_obitos_total taxa_obitos_homem  taxa_obitos_mulher  \
# 0        ...           0.000000               0.0            0.000000
# 1        ...           0.000000               0.0            0.000000
# 2        ...           0.000000               0.0            0.000000
# 3        ...           0.000000               0.0            0.000000
# 4        ...           0.000000               0.0            0.000000
# ...      ...                ...               ...                 ...
# 1835995  ...          66.357001               0.0          102.145046
# 1835996  ...           0.000000               0.0            0.000000
# 1835997  ...           0.000000               0.0            0.000000
# 1835998  ...           0.000000               0.0            0.000000
# 1835999  ...           0.000000               0.0            0.000000
#
#          obitos_esp_total  obitos_esp_homem  obitos_esp_mulher  \
# 0                0.000000               0.0           0.000000
# 1                0.000000               0.0           0.000000
# 2                0.000000               0.0           0.000000
# 3                0.000000               0.0           0.000000
# 4                0.000000               0.0           0.000000
# ...                   ...               ...                ...
# 1835995        221.985401               0.0         209.500511
# 1835996          0.000000               0.0           0.000000
# 1835997          0.000000               0.0           0.000000
# 1835998          0.000000               0.0           0.000000
# 1835999          0.000000               0.0           0.000000
#
#          taxa_obitos_esp_total  taxa_obitos_esp_homem  taxa_obitos_esp_mulher  \
# 0                     0.000000                    0.0                0.000000
# 1                     0.000000                    0.0                0.000000
# 2                     0.000000                    0.0                0.000000
# 3                     0.000000                    0.0                0.000000
# 4                     0.000000                    0.0                0.000000
# ...                        ...                    ...                     ...
# 1835995              66.357001                    0.0              102.145046
# 1835996               0.000000                    0.0                0.000000
# 1835997               0.000000                    0.0                0.000000
# 1835998               0.000000                    0.0                0.000000
# 1835999               0.000000                    0.0                0.000000
#
#          grupo
# 0          2.0
# 1          2.0
# 2          2.0
# 3          2.0
# 4          2.0
# ...        ...
# 1835995    3.0
# 1835996    3.0
# 1835997    3.0
# 1835998    3.0
# 1835999    3.0
#
# [1836000 rows x 25 columns]

# %%
df['id_municipio'] = df['id_municipio'].astype('uint32')
df['ano'] = df['ano'].astype('uint16')
df['pop_total'] = df['pop_total'].astype('uint64')
df['pop_pad_total'] = df['pop_pad_total'].astype('uint64')
df['pop_homem'] = df['pop_homem'].astype('uint64')
df['pop_pad_homem'] = df['pop_pad_homem'].astype('uint64')
df['pop_mulher'] = df['pop_mulher'].astype('uint64')
df['pop_pad_mulher'] = df['pop_pad_mulher'].astype('uint64')
df['mes'] = df['mes'].astype('uint8')
df['obitos_total'] = df['obitos_total'].astype('uint32')
df['obitos_homem'] = df['obitos_homem'].astype('uint32')
df['obitos_mulher'] = df['obitos_mulher'].astype('uint32')
df['taxa_obitos_total'] = df['taxa_obitos_total'].astype('float32')
df['taxa_obitos_homem'] = df['taxa_obitos_homem'].astype('float32')
df['taxa_obitos_mulher'] = df['taxa_obitos_mulher'].astype('float32')
df['obitos_esp_total'] = df['obitos_esp_total'].astype('float32')
df['obitos_esp_homem'] = df['obitos_esp_homem'].astype('float32')
df['obitos_esp_mulher'] = df['obitos_esp_mulher'].astype('float32')
df['grupo'] = df['grupo'].astype('uint8')
df['taxa_obitos_esp_total'] = df['taxa_obitos_esp_total'].astype('float32')
df['taxa_obitos_esp_homem'] = df['taxa_obitos_esp_homem'].astype('float32')
df['taxa_obitos_esp_mulher'] = df['taxa_obitos_esp_mulher'].astype('float32')

df.to_hdf("pre_taxa_sim_cap.h5", "df")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1836000 entries, 0 to 1835999
# Data columns (total 25 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   municipio               object
#  1   id_municipio            uint32
#  2   ano                     uint16
#  3   faixa_etaria            object
#  4   pop_total               uint64
#  5   pop_pad_total           uint64
#  6   pop_homem               uint64
#  7   pop_pad_homem           uint64
#  8   pop_mulher              uint64
#  9   pop_pad_mulher          uint64
#  10  mes                     uint8
#  11  capitulo                object
#  12  obitos_total            uint32
#  13  obitos_homem            uint32
#  14  obitos_mulher           uint32
#  15  taxa_obitos_total       float32
#  16  taxa_obitos_homem       float32
#  17  taxa_obitos_mulher      float32
#  18  obitos_esp_total        float32
#  19  obitos_esp_homem        float32
#  20  obitos_esp_mulher       float32
#  21  taxa_obitos_esp_total   float32
#  22  taxa_obitos_esp_homem   float32
#  23  taxa_obitos_esp_mulher  float32
#  24  grupo                   uint8
# dtypes: float32(9), object(3), uint16(1), uint32(4), uint64(6), uint8(2)
# memory usage: 224.1+ MB

# %%
df_sf = df.groupby(['municipio', 'id_municipio', 'ano', 'mes', 'capitulo', 'grupo'], as_index=False).sum()

# %%
df_sf['taxa_obitos_total'] = (df_sf['obitos_total'] / df_sf['pop_total']) * 100000
df_sf['taxa_obitos_homem'] = (df_sf['obitos_homem'] / df_sf['pop_homem']) * 100000
df_sf['taxa_obitos_mulher'] = (df_sf['obitos_mulher'] / df_sf['pop_mulher']) * 100000

df_sf['taxa_obitos_esp_total'] = (df_sf['obitos_esp_total'] / df_sf['pop_pad_total']) * 100000
df_sf['taxa_obitos_esp_homem'] = (df_sf['obitos_esp_homem'] / df_sf['pop_pad_homem']) * 100000
df_sf['taxa_obitos_esp_mulher'] = (df_sf['obitos_esp_mulher'] / df_sf['pop_pad_mulher']) * 100000

# %%
df_sf
# Out:
#          municipio  id_municipio   ano  mes capitulo  grupo  pop_total  \
# 0           Abaeté        310020  2010    1        I      2      23107
# 1           Abaeté        310020  2010    1       IV      2      23107
# 2           Abaeté        310020  2010    1       IX      2      23107
# 3           Abaeté        310020  2010    1        V      2      23107
# 4           Abaeté        310020  2010    1        X      2      23107
# ...            ...           ...   ...  ...      ...    ...        ...
# 107995  Vespasiano        317120  2019   12        X      3     127601
# 107996  Vespasiano        317120  2019   12      XII      3     127601
# 107997  Vespasiano        317120  2019   12      XIV      3     127601
# 107998  Vespasiano        317120  2019   12      XVI      3     127601
# 107999  Vespasiano        317120  2019   12       XX      3     127601
#
#         pop_pad_total  pop_homem  pop_pad_homem  ...  obitos_mulher  \
# 0            19957444      11442        9828254  ...              0
# 1            19957444      11442        9828254  ...              0
# 2            19957444      11442        9828254  ...              1
# 3            19957444      11442        9828254  ...              0
# 4            19957444      11442        9828254  ...              0
# ...               ...        ...            ...  ...            ...
# 107995       19957444      61757        9828254  ...              1
# 107996       19957444      61757        9828254  ...              0
# 107997       19957444      61757        9828254  ...              0
# 107998       19957444      61757        9828254  ...              0
# 107999       19957444      61757        9828254  ...              0
#
#         taxa_obitos_total  taxa_obitos_homem  taxa_obitos_mulher  \
# 0                0.000000           0.000000            0.000000
# 1                0.000000           0.000000            0.000000
# 2               12.983079          17.479462            8.572653
# 3                0.000000           0.000000            0.000000
# 4                0.000000           0.000000            0.000000
# ...                   ...                ...                 ...
# 107995           1.567386           1.619250            1.518741
# 107996           0.000000           0.000000            0.000000
# 107997           0.000000           0.000000            0.000000
# 107998           0.000000           0.000000            0.000000
# 107999           0.000000           0.000000            0.000000
#
#         obitos_esp_total  obitos_esp_homem  obitos_esp_mulher  \
# 0               0.000000          0.000000           0.000000
# 1               0.000000          0.000000           0.000000
# 2            2111.514893       1405.498779         705.316528
# 3               0.000000          0.000000           0.000000
# 4               0.000000          0.000000           0.000000
# ...                  ...               ...                ...
# 107995        412.022888        203.195404         209.500504
# 107996          0.000000          0.000000           0.000000
# 107997          0.000000          0.000000           0.000000
# 107998          0.000000          0.000000           0.000000
# 107999          0.000000          0.000000           0.000000
#
#         taxa_obitos_esp_total  taxa_obitos_esp_homem  taxa_obitos_esp_mulher
# 0                    0.000000               0.000000                0.000000
# 1                    0.000000               0.000000                0.000000
# 2                   10.580087              14.300595                6.963208
# 3                    0.000000               0.000000                0.000000
# 4                    0.000000               0.000000                0.000000
# ...                       ...                    ...                     ...
# 107995               2.064507               2.067462                2.068285
# 107996               0.000000               0.000000                0.000000
# 107997               0.000000               0.000000                0.000000
# 107998               0.000000               0.000000                0.000000
# 107999               0.000000               0.000000                0.000000
#
# [108000 rows x 24 columns]

# %%
df_sf.to_csv('taxa_sim_cap.csv', index=False)

# %%
df_sf['id_municipio'] = df_sf['id_municipio'].astype('uint32')
df_sf['ano'] = df_sf['ano'].astype('uint16')
df_sf['pop_total'] = df_sf['pop_total'].astype('uint64')
df_sf['pop_pad_total'] = df_sf['pop_pad_total'].astype('uint64')
df_sf['pop_homem'] = df_sf['pop_homem'].astype('uint64')
df_sf['pop_pad_homem'] = df_sf['pop_pad_homem'].astype('uint64')
df_sf['pop_mulher'] = df_sf['pop_mulher'].astype('uint64')
df_sf['pop_pad_mulher'] = df_sf['pop_pad_mulher'].astype('uint64')
df_sf['mes'] = df_sf['mes'].astype('uint8')
df_sf['obitos_total'] = df_sf['obitos_total'].astype('uint32')
df_sf['obitos_homem'] = df_sf['obitos_homem'].astype('uint32')
df_sf['obitos_mulher'] = df_sf['obitos_mulher'].astype('uint32')
df_sf['taxa_obitos_total'] = df_sf['taxa_obitos_total'].astype('float32')
df_sf['taxa_obitos_homem'] = df_sf['taxa_obitos_homem'].astype('float32')
df_sf['taxa_obitos_mulher'] = df_sf['taxa_obitos_mulher'].astype('float32')
df_sf['obitos_esp_total'] = df_sf['obitos_esp_total'].astype('float32')
df_sf['obitos_esp_homem'] = df_sf['obitos_esp_homem'].astype('float32')
df_sf['obitos_esp_mulher'] = df_sf['obitos_esp_mulher'].astype('float32')
df_sf['grupo'] = df_sf['grupo'].astype('uint8')
df_sf['taxa_obitos_esp_total'] = df_sf['taxa_obitos_esp_total'].astype('float32')
df_sf['taxa_obitos_esp_homem'] = df_sf['taxa_obitos_esp_homem'].astype('float32')
df_sf['taxa_obitos_esp_mulher'] = df_sf['taxa_obitos_esp_mulher'].astype('float32')

df_sf.to_hdf('taxa_sim_cap.h5', "df_sf")

df_sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108000 entries, 0 to 107999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   municipio               108000 non-null  object
#  1   id_municipio            108000 non-null  uint32
#  2   ano                     108000 non-null  uint16
#  3   mes                     108000 non-null  uint8
#  4   capitulo                108000 non-null  object
#  5   grupo                   108000 non-null  uint8
#  6   pop_total               108000 non-null  uint64
#  7   pop_pad_total           108000 non-null  uint64
#  8   pop_homem               108000 non-null  uint64
#  9   pop_pad_homem           108000 non-null  uint64
#  10  pop_mulher              108000 non-null  uint64
#  11  pop_pad_mulher          108000 non-null  uint64
#  12  obitos_total            108000 non-null  uint32
#  13  obitos_homem            108000 non-null  uint32
#  14  obitos_mulher           108000 non-null  uint32
#  15  taxa_obitos_total       108000 non-null  float32
#  16  taxa_obitos_homem       108000 non-null  float32
#  17  taxa_obitos_mulher      108000 non-null  float32
#  18  obitos_esp_total        108000 non-null  float32
#  19  obitos_esp_homem        108000 non-null  float32
#  20  obitos_esp_mulher       108000 non-null  float32
#  21  taxa_obitos_esp_total   108000 non-null  float32
#  22  taxa_obitos_esp_homem   108000 non-null  float32
#  23  taxa_obitos_esp_mulher  108000 non-null  float32
# dtypes: float32(9), object(2), uint16(1), uint32(4), uint64(6), uint8(2)
# memory usage: 13.2+ MB

# %%
df_sf[df_sf['municipio'] == 'Brumadinho']
# Out:
#         municipio  id_municipio   ano  mes capitulo  grupo  pop_total  \
# 11880  Brumadinho        310900  2010    1        I      1      34597
# 11881  Brumadinho        310900  2010    1       IV      1      34597
# 11882  Brumadinho        310900  2010    1       IX      1      34597
# 11883  Brumadinho        310900  2010    1        V      1      34597
# 11884  Brumadinho        310900  2010    1        X      1      34597
# ...           ...           ...   ...  ...      ...    ...        ...
# 12955  Brumadinho        310900  2019   12        X      1      40103
# 12956  Brumadinho        310900  2019   12      XII      1      40103
# 12957  Brumadinho        310900  2019   12      XIV      1      40103
# 12958  Brumadinho        310900  2019   12      XVI      1      40103
# 12959  Brumadinho        310900  2019   12       XX      1      40103
#
#        pop_pad_total  pop_homem  pop_pad_homem  ...  obitos_mulher  \
# 11880       19957444      17353        9828254  ...              0
# 11881       19957444      17353        9828254  ...              0
# 11882       19957444      17353        9828254  ...              1
# 11883       19957444      17353        9828254  ...              0
# 11884       19957444      17353        9828254  ...              0
# ...              ...        ...            ...  ...            ...
# 12955       19957444      20167        9828254  ...              0
# 12956       19957444      20167        9828254  ...              0
# 12957       19957444      20167        9828254  ...              0
# 12958       19957444      20167        9828254  ...              0
# 12959       19957444      20167        9828254  ...              0
#
#        taxa_obitos_total  taxa_obitos_homem  taxa_obitos_mulher  \
# 11880           0.000000           0.000000            0.000000
# 11881           0.000000           0.000000            0.000000
# 11882           5.780848           5.762692            5.799119
# 11883           0.000000           0.000000            0.000000
# 11884           0.000000           0.000000            0.000000
# ...                  ...                ...                 ...
# 12955           0.000000           0.000000            0.000000
# 12956           0.000000           0.000000            0.000000
# 12957           0.000000           0.000000            0.000000
# 12958           0.000000           0.000000            0.000000
# 12959           0.000000           0.000000            0.000000
#
#        obitos_esp_total  obitos_esp_homem  obitos_esp_mulher  \
# 11880          0.000000          0.000000           0.000000
# 11881          0.000000          0.000000           0.000000
# 11882       1218.349731        637.591125         623.129211
# 11883          0.000000          0.000000           0.000000
# 11884          0.000000          0.000000           0.000000
# ...                 ...               ...                ...
# 12955          0.000000          0.000000           0.000000
# 12956          0.000000          0.000000           0.000000
# 12957          0.000000          0.000000           0.000000
# 12958          0.000000          0.000000           0.000000
# 12959          0.000000          0.000000           0.000000
#
#        taxa_obitos_esp_total  taxa_obitos_esp_homem  taxa_obitos_esp_mulher
# 11880               0.000000               0.000000                0.000000
# 11881               0.000000               0.000000                0.000000
# 11882               6.104738               6.487329                6.151817
# 11883               0.000000               0.000000                0.000000
# 11884               0.000000               0.000000                0.000000
# ...                      ...                    ...                     ...
# 12955               0.000000               0.000000                0.000000
# 12956               0.000000               0.000000                0.000000
# 12957               0.000000               0.000000                0.000000
# 12958               0.000000               0.000000                0.000000
# 12959               0.000000               0.000000                0.000000
#
# [1080 rows x 24 columns]
