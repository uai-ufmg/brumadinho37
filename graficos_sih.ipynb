# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import altair as alt

df = pd.read_csv("pre_taxa_sih.csv")

df = df[~df['agravo'].isin(['exttrauma', 'extmorbmort', 'extintind', 'homicidio', 'suicidio', 'acidente', 'externas_S'])]

df.loc[df['agravo'] == 'externas', 'agravo'] = 'lesoes'

df
# Out:
#            municipio  id_municipio   ano faixa_etaria  pop_total  \
# 0             Abaeté        310020  2010          0a4       1377
# 1             Abaeté        310020  2010          0a4       1377
# 2             Abaeté        310020  2010          0a4       1377
# 3             Abaeté        310020  2010          0a4       1377
# 4             Abaeté        310020  2010          0a4       1377
# ...              ...           ...   ...          ...        ...
# 14891994  Vespasiano        317120  2019     >=80anos       1507
# 14891995  Vespasiano        317120  2019     >=80anos       1507
# 14891997  Vespasiano        317120  2019     >=80anos       1507
# 14891998  Vespasiano        317120  2019     >=80anos       1507
# 14891999  Vespasiano        317120  2019     >=80anos       1507
#
#           pop_pad_total  pop_homem  pop_pad_homem  pop_mulher  pop_pad_mulher  \
# 0               1338553        702         684629         675          653924
# 1               1338553        702         684629         675          653924
# 2               1338553        702         684629         675          653924
# 3               1338553        702         684629         675          653924
# 4               1338553        702         684629         675          653924
# ...                 ...        ...            ...         ...             ...
# 14891994         334532        528         129431         979          205101
# 14891995         334532        528         129431         979          205101
# 14891997         334532        528         129431         979          205101
# 14891998         334532        528         129431         979          205101
# 14891999         334532        528         129431         979          205101
#
#           mes      agravo  inter_total  inter_homem  inter_mulher  grupo
# 0           1      colera            0            0             0    2.0
# 1           1    diarreia            0            0             0    2.0
# 2           1        odip            2            2             0    2.0
# 3           1     tubresp            0            0             0    2.0
# 4           1  tbsistnerv            0            0             0    2.0
# ...       ...         ...          ...          ...           ...    ...
# 14891994   12  outraspele            0            0             0    3.0
# 14891995   12      veneno            0            0             0    3.0
# 14891997   12  externas_T            0            0             0    3.0
# 14891998   12       total            6            6             6    3.0
# 14891999   12    naturais            6            6             6    3.0
#
# [13464000 rows x 16 columns]

# %%
df_19 = df[df['ano'] == 2019]
df_19 = df_19.groupby(['agravo', 'grupo'], as_index=False).sum()

df_19['pop_total'] = df_19['pop_total'] / 12
df_19['pop_homem'] = df_19['pop_homem'] / 12
df_19['pop_mulher'] = df_19['pop_mulher'] / 12


df_19['taxa_nova_total'] = np.nan
df_19['taxa_nova_homem'] = np.nan
df_19['taxa_nova_mulher'] = np.nan

df_19['taxa_nova_total'] = (df_19['inter_total']/df_19['pop_total'])*100000
df_19['taxa_nova_homem'] = (df_19['inter_homem']/df_19['pop_homem'])*100000
df_19['taxa_nova_mulher'] = (df_19['inter_mulher']/df_19['pop_mulher'])*100000

df_19
# Out:
#         agravo  grupo  id_municipio       ano  pop_total  pop_pad_total  \
# 0     amebiase    1.0    1216548900   7825644   987038.0     4550297232
# 1     amebiase    2.0    2556087360  16475040  4601121.0     9579573120
# 2     amebiase    3.0    2625678288  16886916  1153419.0     9819062448
# 3    ancilosto    1.0    1216548900   7825644   987038.0     4550297232
# 4    ancilosto    2.0    2556087360  16475040  4601121.0     9579573120
# ..         ...    ...           ...       ...        ...            ...
# 193    tubresp    2.0    2556087360  16475040  4601121.0     9579573120
# 194    tubresp    3.0    2625678288  16886916  1153419.0     9819062448
# 195     veneno    1.0    1216548900   7825644   987038.0     4550297232
# 196     veneno    2.0    2556087360  16475040  4601121.0     9579573120
# 197     veneno    3.0    2625678288  16886916  1153419.0     9819062448
#
#      pop_homem  pop_pad_homem  pop_mulher  pop_pad_mulher    mes  inter_total  \
# 0     490872.0     2240841912    496166.0      2309455320  25194            0
# 1    2197563.0     4717561920   2403558.0      4862011200  53040            0
# 2     568618.0     4835500968    584801.0      4983561480  54366            1
# 3     490872.0     2240841912    496166.0      2309455320  25194            0
# 4    2197563.0     4717561920   2403558.0      4862011200  53040            0
# ..         ...            ...         ...             ...    ...          ...
# 193  2197563.0     4717561920   2403558.0      4862011200  53040          351
# 194   568618.0     4835500968    584801.0      4983561480  54366           58
# 195   490872.0     2240841912    496166.0      2309455320  25194            0
# 196  2197563.0     4717561920   2403558.0      4862011200  53040            0
# 197   568618.0     4835500968    584801.0      4983561480  54366            0
#
#      inter_homem  inter_mulher  taxa_nova_total  taxa_nova_homem  \
# 0              0             0         0.000000         0.000000
# 1              0             0         0.000000         0.000000
# 2              1             0         0.086699         0.175865
# 3              0             0         0.000000         0.000000
# 4              0             0         0.000000         0.000000
# ..           ...           ...              ...              ...
# 193          284            67         7.628576        12.923407
# 194           49             9         5.028528         8.617385
# 195            0             0         0.000000         0.000000
# 196            0             0         0.000000         0.000000
# 197            0             0         0.000000         0.000000
#
#      taxa_nova_mulher
# 0            0.000000
# 1            0.000000
# 2            0.000000
# 3            0.000000
# 4            0.000000
# ..                ...
# 193          2.787534
# 194          1.538985
# 195          0.000000
# 196          0.000000
# 197          0.000000
#
# [198 rows x 17 columns]

# %%
df_r = df[df['ano'] != 2019]
df_r = df_r.groupby(['agravo', 'grupo'], as_index=False).sum()

df_r['pop_total'] = df_r['pop_total'] / 12
df_r['pop_homem'] = df_r['pop_homem'] / 12
df_r['pop_mulher'] = df_r['pop_mulher'] / 12

df_r['taxa_nova_total'] = np.nan
df_r['taxa_nova_homem'] = np.nan
df_r['taxa_nova_mulher'] = np.nan

df_r['taxa_nova_total'] = (df_r['inter_total']/df_r['pop_total'])*100000
df_r['taxa_nova_homem'] = (df_r['inter_homem']/df_r['pop_homem'])*100000
df_r['taxa_nova_mulher'] = (df_r['inter_mulher']/df_r['pop_mulher'])*100000

df_r
# Out:
#         agravo  grupo  id_municipio        ano   pop_total  pop_pad_total  \
# 0     amebiase    1.0   10948940100   70256376   8310203.0    40952675088
# 1     amebiase    2.0   23004786240  147908160  40120632.0    86216158080
# 2     amebiase    3.0   23631104592  151605864   9818311.0    88371562032
# 3    ancilosto    1.0   10948940100   70256376   8310203.0    40952675088
# 4    ancilosto    2.0   23004786240  147908160  40120632.0    86216158080
# ..         ...    ...           ...        ...         ...            ...
# 193    tubresp    2.0   23004786240  147908160  40120632.0    86216158080
# 194    tubresp    3.0   23631104592  151605864   9818311.0    88371562032
# 195     veneno    1.0   10948940100   70256376   8310203.0    40952675088
# 196     veneno    2.0   23004786240  147908160  40120632.0    86216158080
# 197     veneno    3.0   23631104592  151605864   9818311.0    88371562032
#
#       pop_homem  pop_pad_homem  pop_mulher  pop_pad_mulher     mes  \
# 0     4133773.0    20167577208   4176430.0     20785097880  226746
# 1    19189839.0    42458057280  20930793.0     43758100800  477360
# 2     4845402.0    43519508712   4972909.0     44852053320  489294
# 3     4133773.0    20167577208   4176430.0     20785097880  226746
# 4    19189839.0    42458057280  20930793.0     43758100800  477360
# ..          ...            ...         ...             ...     ...
# 193  19189839.0    42458057280  20930793.0     43758100800  477360
# 194   4845402.0    43519508712   4972909.0     44852053320  489294
# 195   4133773.0    20167577208   4176430.0     20785097880  226746
# 196  19189839.0    42458057280  20930793.0     43758100800  477360
# 197   4845402.0    43519508712   4972909.0     44852053320  489294
#
#      inter_total  inter_homem  inter_mulher  taxa_nova_total  taxa_nova_homem  \
# 0              4            1             3         0.048134         0.024191
# 1            124           68            56         0.309068         0.354354
# 2             30           17            13         0.305552         0.350848
# 3              0            0             0         0.000000         0.000000
# 4              3            3             0         0.007477         0.015633
# ..           ...          ...           ...              ...              ...
# 193         3281         2509           772         8.177837        13.074628
# 194          397          290           107         4.043465         5.985056
# 195            0            0             0         0.000000         0.000000
# 196            1            1             0         0.002492         0.005211
# 197            0            0             0         0.000000         0.000000
#
#      taxa_nova_mulher
# 0            0.071832
# 1            0.267548
# 2            0.261416
# 3            0.000000
# 4            0.000000
# ..                ...
# 193          3.688346
# 194          2.151658
# 195          0.000000
# 196          0.000000
# 197          0.000000
#
# [198 rows x 17 columns]

# %%
def plot_grafico_dif(df1, df2, taxa, titulo, xlabel):
    aux = (df1.groupby(['grupo', 'agravo'])[taxa].
           sum().
           unstack(0))
    aux2 = (df2.groupby(['grupo', 'agravo'])[taxa].
            sum().
            unstack(0))
    
    aux3 = aux - aux2
    
    df = (aux3.sort_values(ascending=False, by=1.0).
         head(15))
    df = df.stack().reset_index().rename(columns={ 0: 'taxa' })
    df['grupo'] = df['grupo'].astype(str)

    c = alt.Chart(df, title=titulo).mark_bar().encode(
        alt.Color('grupo:N', title='Grupo'),
        alt.Y('agravo:N', title='Agravo', sort=None),
        alt.X('taxa:Q', title=xlabel, scale=alt.Scale(domain=[-40, 150])),
        alt.Order('grupo:N', sort='ascending'),
        alt.Tooltip('taxa:Q')
    ).properties(
        width=640,
    ).configure_range(
        category={'scheme': 'set1'}
    )
    
    return c

# %%
chart = plot_grafico_dif(df_19, df_r,
                         'taxa_nova_total', 
                         "Agravos com maior direfença da razão internações/população entre 2019 e o resto do período - Total",
                        "Diferença da Razão internações/população (a cada 100.000 habitantes)")

#chart.save('tx_bruta_t.svg')
chart
# Out:
# alt.Chart(...)

# %%
chart = plot_grafico_dif(df_19, df_r,
                         'taxa_nova_homem', 
                         "Agravos com maior direfença da razão internações/população entre 2019 e o resto do período - Homens",
                        "Diferença da Razão internações/população de homens (a cada 100.000 habitantes)")

#chart.save('tx_bruta_t.svg')
chart
# Out:
# alt.Chart(...)

# %%
chart = plot_grafico_dif(df_19, df_r,
                         'taxa_nova_mulher', 
                         "Agravos com maior direfença da razão internações/população entre 2019 e o resto do período - Mulheres",
                        "Diferença da Razão internações/população de mulheres (a cada 100.000 habitantes)")

#chart.save('tx_bruta_t.svg')
chart
# Out:
# alt.Chart(...)
