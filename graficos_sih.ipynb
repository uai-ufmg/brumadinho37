# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import altair as alt

df = pd.read_csv("pre_taxa_sih.csv")
df
# Out:
#            municipio  id_municipio   ano faixa_etaria  pop_total  \
# 0             Abaeté        310020  2010          0a4       1377
# 1             Abaeté        310020  2010          0a4       1377
# 2             Abaeté        310020  2010          0a4       1377
# 3             Abaeté        310020  2010          0a4       1377
# 4             Abaeté        310020  2010          0a4       1377
# ...              ...           ...   ...          ...        ...
# 13463995  Vespasiano        317120  2019     >=80anos       1507
# 13463996  Vespasiano        317120  2019     >=80anos       1507
# 13463997  Vespasiano        317120  2019     >=80anos       1507
# 13463998  Vespasiano        317120  2019     >=80anos       1507
# 13463999  Vespasiano        317120  2019     >=80anos       1507
#
#           pop_pad_total  pop_homem  pop_pad_homem  pop_mulher  pop_pad_mulher  \
# 0               1338553        702         684629         675          653924
# 1               1338553        702         684629         675          653924
# 2               1338553        702         684629         675          653924
# 3               1338553        702         684629         675          653924
# 4               1338553        702         684629         675          653924
# ...                 ...        ...            ...         ...             ...
# 13463995         334532        528         129431         979          205101
# 13463996         334532        528         129431         979          205101
# 13463997         334532        528         129431         979          205101
# 13463998         334532        528         129431         979          205101
# 13463999         334532        528         129431         979          205101
#
#           ...  taxa_inter_total taxa_inter_homem  taxa_inter_mulher  \
# 0         ...          0.000000         0.000000           0.000000
# 1         ...          0.000000         0.000000           0.000000
# 2         ...        145.243282       284.900285           0.000000
# 3         ...          0.000000         0.000000           0.000000
# 4         ...          0.000000         0.000000           0.000000
# ...       ...               ...              ...                ...
# 13463995  ...          0.000000         0.000000           0.000000
# 13463996  ...         66.357001         0.000000         102.145046
# 13463997  ...          0.000000         0.000000           0.000000
# 13463998  ...          0.000000         0.000000           0.000000
# 13463999  ...          0.000000         0.000000           0.000000
#
#           inter_esp_total  inter_esp_homem  inter_esp_mulher  \
# 0                0.000000         0.000000          0.000000
# 1                0.000000         0.000000          0.000000
# 2             1944.158315      1950.509972          0.000000
# 3                0.000000         0.000000          0.000000
# 4                0.000000         0.000000          0.000000
# ...                   ...              ...               ...
# 13463995         0.000000         0.000000          0.000000
# 13463996       221.985401         0.000000        209.500511
# 13463997         0.000000         0.000000          0.000000
# 13463998         0.000000         0.000000          0.000000
# 13463999         0.000000         0.000000          0.000000
#
#           taxa_inter_esp_total  taxa_inter_esp_homem  taxa_inter_esp_mulher  \
# 0                     0.000000              0.000000               0.000000
# 1                     0.000000              0.000000               0.000000
# 2                   145.243282            284.900285               0.000000
# 3                     0.000000              0.000000               0.000000
# 4                     0.000000              0.000000               0.000000
# ...                        ...                   ...                    ...
# 13463995              0.000000              0.000000               0.000000
# 13463996             66.357001              0.000000             102.145046
# 13463997              0.000000              0.000000               0.000000
# 13463998              0.000000              0.000000               0.000000
# 13463999              0.000000              0.000000               0.000000
#
#           grupo
# 0           2.0
# 1           2.0
# 2           2.0
# 3           2.0
# 4           2.0
# ...         ...
# 13463995    3.0
# 13463996    3.0
# 13463997    3.0
# 13463998    3.0
# 13463999    3.0
#
# [13464000 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['municipio', 'id_municipio', 'ano', 'faixa_etaria', 'pop_total',
#        'pop_pad_total', 'pop_homem', 'pop_pad_homem', 'pop_mulher',
#        'pop_pad_mulher', 'mes', 'agravo', 'inter_total', 'inter_homem',
#        'inter_mulher', 'taxa_inter_total', 'taxa_inter_homem',
#        'taxa_inter_mulher', 'inter_esp_total', 'inter_esp_homem',
#        'inter_esp_mulher', 'taxa_inter_esp_total', 'taxa_inter_esp_homem',
#        'taxa_inter_esp_mulher', 'grupo'],
#       dtype='object')

# %%
df_filtro = df.groupby(['municipio', 'id_municipio', 'grupo', 'ano', 'mes', 'agravo'], as_index=False).sum()

df_total = df.groupby(['id_municipio', 'grupo', 'ano', 'mes'], as_index=False)[['inter_total', 'inter_homem', 'inter_mulher']].sum()
df_total.columns = ['id_municipio', 'grupo', 'ano', 'mes', 'total_inter_loc', 'homem_inter_loc', 'mulher_inter_loc']

df_total = df_filtro.merge(df_total, on=['id_municipio', 'grupo', 'ano', 'mes'])
df_total['taxa_nova_total'] = np.nan
df_total['taxa_nova_homem'] = np.nan
df_total['taxa_nova_mulher'] = np.nan

df_total['taxa_nova_total'] = (df_total['inter_total']/df_total['pop_total'])*100000
df_total['taxa_nova_homem'] = (df_total['inter_homem']/df_total['pop_homem'])*100000
df_total['taxa_nova_mulher'] = (df_total['inter_mulher']/df_total['pop_mulher'])*100000

#df_total[df_total['taxa_nova'] > 0]

# %%
df = df_total

# %%
df_19 = df[df['ano'] == 2019]
df_19 = df_19.groupby(['agravo', 'grupo'], as_index=False).sum()

# %%
df_19[df_19['agravo'] == "amebiase"]["inter_total"].sum()
# Out:
# 1

# %%
df_r = df[df['ano'] != 2019]
df_r = df_r.groupby(['ano', 'agravo', 'grupo'], as_index=False).sum()
df_r = df_r.groupby(['agravo', 'grupo'], as_index=False).mean()
df_r
# Out:
#        agravo  grupo     ano  id_municipio     mes     pop_total  \
# 0    agressao    1.0  2014.0    71561700.0  1482.0  1.108027e+07
# 1    agressao    2.0  2014.0   150358080.0  3120.0  5.349418e+07
# 2    agressao    3.0  2014.0   154451664.0  3198.0  1.309108e+07
# 3    amebiase    1.0  2014.0    71561700.0  1482.0  1.108027e+07
# 4    amebiase    2.0  2014.0   150358080.0  3120.0  5.349418e+07
# ..        ...    ...     ...           ...     ...           ...
# 193   tubresp    2.0  2014.0   150358080.0  3120.0  5.349418e+07
# 194   tubresp    3.0  2014.0   154451664.0  3198.0  1.309108e+07
# 195    veneno    1.0  2014.0    71561700.0  1482.0  1.108027e+07
# 196    veneno    2.0  2014.0   150358080.0  3120.0  5.349418e+07
# 197    veneno    3.0  2014.0   154451664.0  3198.0  1.309108e+07
#
#      pop_pad_total     pop_homem  pop_pad_homem    pop_mulher  ...  \
# 0     4.550297e+09  5.511697e+06   2.240842e+09  5.568573e+06  ...
# 1     9.579573e+09  2.558645e+07   4.717562e+09  2.790772e+07  ...
# 2     9.819062e+09  6.460536e+06   4.835501e+09  6.630545e+06  ...
# 3     4.550297e+09  5.511697e+06   2.240842e+09  5.568573e+06  ...
# 4     9.579573e+09  2.558645e+07   4.717562e+09  2.790772e+07  ...
# ..             ...           ...            ...           ...  ...
# 193   9.579573e+09  2.558645e+07   4.717562e+09  2.790772e+07  ...
# 194   9.819062e+09  6.460536e+06   4.835501e+09  6.630545e+06  ...
# 195   4.550297e+09  5.511697e+06   2.240842e+09  5.568573e+06  ...
# 196   9.579573e+09  2.558645e+07   4.717562e+09  2.790772e+07  ...
# 197   9.819062e+09  6.460536e+06   4.835501e+09  6.630545e+06  ...
#
#      inter_esp_mulher  taxa_inter_esp_total  taxa_inter_esp_homem  \
# 0           49.802579             49.185578             88.717124
# 1            0.000000             24.875216             48.984976
# 2            0.000000             30.390801             58.952191
# 3          112.623391             18.491925              4.040404
# 4         5874.891433           1101.709959           1075.467644
# ..                ...                   ...                   ...
# 193       6423.846244           2684.613272           4421.963685
# 194       7551.531461           2848.186205           4670.015964
# 195          0.000000              0.000000              0.000000
# 196          0.000000              0.000000              0.000000
# 197          0.000000              0.000000              0.000000
#
#      taxa_inter_esp_mulher  total_inter_loc  homem_inter_loc  \
# 0                 5.926256      8085.000000      4523.444444
# 1                 0.000000     47717.666667     26624.777778
# 2                 0.000000     11773.222222      6544.222222
# 3                31.968289      8085.000000      4523.444444
# 4              1122.899326     47717.666667     26624.777778
# ..                     ...              ...              ...
# 193            1088.842980     47717.666667     26624.777778
# 194            1084.919025     11773.222222      6544.222222
# 195               0.000000      8085.000000      4523.444444
# 196               0.000000     47717.666667     26624.777778
# 197               0.000000     11773.222222      6544.222222
#
#      mulher_inter_loc  taxa_nova_total  taxa_nova_homem  taxa_nova_mulher
# 0         3561.555556         3.535141         6.561870          0.505247
# 1        21092.888889         1.564967         3.078476          0.000000
# 2         5229.000000         2.584163         5.141468          0.000000
# 3         3561.555556         0.673526         0.247254          1.099781
# 4        21092.888889        55.256338        52.618894         57.774891
# ..                ...              ...              ...               ...
# 193      21092.888889       142.028353       219.998225         64.823307
# 194       5229.000000       175.770096       277.588174         67.617364
# 195       3561.555556         0.000000         0.000000          0.000000
# 196      21092.888889         0.000000         0.000000          0.000000
# 197       5229.000000         0.000000         0.000000          0.000000
#
# [198 rows x 29 columns]

# %%
def plot_grafico_dif(df1, df2, taxa, titulo, xlabel):
    aux = (df1.groupby(['grupo', 'agravo'])[taxa].
           sum().
           unstack(0))
    aux2 = (df2.groupby(['grupo', 'agravo'])[taxa].
            sum().
            unstack(0))
    
    aux3 = aux - aux2
    
    df = (aux3.sort_values(ascending=False, by=1.0).
         head(15))
    df = df.stack().reset_index().rename(columns={ 0: 'taxa' })
    df['grupo'] = df['grupo'].astype(str)

    c = alt.Chart(df, title=titulo).mark_bar().encode(
        alt.Color('grupo:N', title='Grupo'),
        alt.Y('agravo:N', title='Agravo', sort=None),
        alt.X('taxa:Q', title=xlabel),
        alt.Order('grupo:N', sort='ascending'),
        alt.Tooltip('taxa:Q')
    ).properties(
        width=640,
    ).configure_range(
        category={'scheme': 'set1'}
    )
    
    return c

# %%
chart = plot_grafico_dif(df_19, df_r,
                         'inter_total', 
                         "Agravos com maior diferença absoluta de internações para 2019 - Total",
                        "Diferença absoluta de internações")

#chart.save('tx_bruta_t.svg')
chart
# Out:
# alt.Chart(...)

# %%
chart = plot_grafico_dif(df_19, df_r,
                         'inter_homem', 
                         "Agravos com maior diferença absoluta de internações para 2019 - Homens",
                        "Diferença absoluta de internações masculina")

#chart.save('tx_bruta_h.svg')
chart
# Out:
# alt.Chart(...)

# %%
chart = plot_grafico_dif(df_19, df_r,
                         'inter_mulher', 
                         "Agravos com maior diferença absoluta de internações para 2019 - Mulheres",
                        "Diferença absoluta de internações feminina")


#chart.save('tx_bruta_m.svg')
chart
# Out:
# alt.Chart(...)

# %%
chart = plot_grafico_dif(df_19, df_r,
                         'taxa_nova_total', 
                         "Agravos com maior razão internações/população para 2019 - Total",
                        "Razão internações/população (a cada 100.000 habitantes)")

#chart.save('tx_bruta_t.svg')
chart
# Out:
# alt.Chart(...)

# %%
chart = plot_grafico_dif(df_19, df_r,
                         'taxa_nova_homem', 
                         "Agravos com maior razão internações/população para 2019 - Homens",
                        "Razão internações/população de homens (a cada 100.000 habitantes)")

#chart.save('tx_bruta_t.svg')
chart
# Out:
# alt.Chart(...)

# %%
chart = plot_grafico_dif(df_19, df_r,
                         'taxa_nova_mulher', 
                         "Agravos com maior razão internações/população para 2019 - Mulheres",
                        "Razão internações/população de mulheres (a cada 100.000 habitantes)")

#chart.save('tx_bruta_t.svg')
chart
# Out:
# alt.Chart(...)
