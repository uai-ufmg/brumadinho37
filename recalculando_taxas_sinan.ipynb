# %%
import pandas as pd
import numpy as np

df = pd.read_csv("pre_taxa_sinan.csv")
df
# Out:
#           municipio  id_municipio   ano faixa_etaria  pop_total  \
# 0            Abaeté        310020  2013          0a4       1309
# 1            Abaeté        310020  2013          0a4       1309
# 2            Abaeté        310020  2013          0a4       1309
# 3            Abaeté        310020  2013          0a4       1309
# 4            Abaeté        310020  2013          0a4       1309
# ...             ...           ...   ...          ...        ...
# 1999195  Vespasiano        317120  2019     >=80anos       1507
# 1999196  Vespasiano        317120  2019     >=80anos       1507
# 1999197  Vespasiano        317120  2019     >=80anos       1507
# 1999198  Vespasiano        317120  2019     >=80anos       1507
# 1999199  Vespasiano        317120  2019     >=80anos       1507
#
#          pop_pad_total  pop_homem  pop_pad_homem  pop_mulher  pop_pad_mulher  \
# 0              1338553        669         684629         640          653924
# ...

# %%
df[df['notificacoes_total'] > 0]
# Out:
#               municipio  id_municipio   ano faixa_etaria  pop_total  \
# 223              Araçaí        310320  2013          0a4        140
# 821              Baldim        310500  2013          0a4        517
# 849      Belo Horizonte        310620  2013          0a4     133385
# 853      Belo Horizonte        310620  2013          0a4     133385
# 863      Belo Horizonte        310620  2013          0a4     133385
# ...                 ...           ...   ...          ...        ...
# 1998757     Sete Lagoas        316720  2019     >=80anos       4656
# 1998771     Sete Lagoas        316720  2019     >=80anos       4656
# 1998785     Sete Lagoas        316720  2019     >=80anos       4656
# 1998953           Tiros        316890  2019     >=80anos        215
# 1999093      Vespasiano        317120  2019     >=80anos       1507
#
#          pop_pad_total  pop_homem  pop_pad_homem  pop_mulher  pop_pad_mulher  \
# ...

# %%
df['id_municipio'] = df['id_municipio'].astype('uint32')
df['ano'] = df['ano'].astype('uint16')
df['pop_total'] = df['pop_total'].astype('uint64')
df['pop_pad_total'] = df['pop_pad_total'].astype('uint64')
df['pop_homem'] = df['pop_homem'].astype('uint64')
df['pop_pad_homem'] = df['pop_pad_homem'].astype('uint64')
df['pop_mulher'] = df['pop_mulher'].astype('uint64')
df['pop_pad_mulher'] = df['pop_pad_mulher'].astype('uint64')
df['mes'] = df['mes'].astype('uint8')
df['notificacoes_total'] = df['notificacoes_total'].astype('uint32')
df['notificacoes_homem'] = df['notificacoes_homem'].astype('uint32')
df['notificacoes_mulher'] = df['notificacoes_mulher'].astype('uint32')
df['grupo'] = df['grupo'].astype('uint8')

#df.to_hdf("pre_taxa_sih.h5", "df")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999200 entries, 0 to 1999199
# Data columns (total 16 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   municipio            object
#  1   id_municipio         uint32
#  2   ano                  uint16
#  3   faixa_etaria         object
#  4   pop_total            uint64
#  5   pop_pad_total        uint64
#  6   pop_homem            uint64
#  7   pop_pad_homem        uint64
#  8   pop_mulher           uint64
#  9   pop_pad_mulher       uint64
#  10  mes                  uint8
#  11  agravo               object
#  12  notificacoes_total   uint32
#  13  notificacoes_homem   uint32
#  14  notificacoes_mulher  uint32
#  15  grupo                uint8
# dtypes: object(3), uint16(1), uint32(4), uint64(6), uint8(2)
# memory usage: 175.4+ MB

# %%
df
# Out:
#           municipio  id_municipio   ano faixa_etaria  pop_total  \
# 0            Abaeté        310020  2013          0a4       1309
# 1            Abaeté        310020  2013          0a4       1309
# 2            Abaeté        310020  2013          0a4       1309
# 3            Abaeté        310020  2013          0a4       1309
# 4            Abaeté        310020  2013          0a4       1309
# ...             ...           ...   ...          ...        ...
# 1999195  Vespasiano        317120  2019     >=80anos       1507
# 1999196  Vespasiano        317120  2019     >=80anos       1507
# 1999197  Vespasiano        317120  2019     >=80anos       1507
# 1999198  Vespasiano        317120  2019     >=80anos       1507
# 1999199  Vespasiano        317120  2019     >=80anos       1507
#
#          pop_pad_total  pop_homem  pop_pad_homem  pop_mulher  pop_pad_mulher  \
# 0              1338553        669         684629         640          653924
# ...

# %%
df_sf = df.groupby(['municipio', 'id_municipio', 'ano', 'agravo', 'grupo'], as_index=False).sum()

# %%
df_sf['pop_total'] = df_sf['pop_total'] / 12
df_sf['pop_homem'] = df_sf['pop_homem'] / 12
df_sf['pop_mulher'] = df_sf['pop_mulher'] / 12

df_sf['taxa_notific_total'] = (df_sf['notificacoes_total'] / df_sf['pop_total']) * 100000
df_sf['taxa_notific_homem'] = (df_sf['notificacoes_homem'] / df_sf['pop_homem']) * 100000
df_sf['taxa_notific_mulher'] = (df_sf['notificacoes_mulher'] / df_sf['pop_mulher']) * 100000

# %%
df_sf.to_csv('taxa_sinan.csv', index=False)

# %%
df_sf
# Out:
#        municipio  id_municipio   ano        agravo  grupo  pop_total  \
# 0         Abaeté        310020  2013        chagas      2    23151.0
# 1         Abaeté        310020  2013        colera      2    23151.0
# 2         Abaeté        310020  2013        dengue      2    23151.0
# 3         Abaeté        310020  2013      esquisto      2    23151.0
# 4         Abaeté        310020  2013  febreamarela      2    23151.0
# ...          ...           ...   ...           ...    ...        ...
# 9795  Vespasiano        317120  2019     leishvisc      3   127601.0
# 9796  Vespasiano        317120  2019         lepto      3   127601.0
# 9797  Vespasiano        317120  2019       malaria      3   127601.0
# 9798  Vespasiano        317120  2019      sindrome      3   127601.0
# 9799  Vespasiano        317120  2019       tubresp      3   127601.0
#
#       pop_pad_total  pop_homem  pop_pad_homem  pop_mulher  pop_pad_mulher  \
# ...

# %%
df_sf['id_municipio'] = df_sf['id_municipio'].astype('uint32')
df_sf['ano'] = df_sf['ano'].astype('uint16')
df_sf['pop_total'] = df_sf['pop_total'].astype('uint64')
df_sf['pop_pad_total'] = df_sf['pop_pad_total'].astype('uint64')
df_sf['pop_homem'] = df_sf['pop_homem'].astype('uint64')
df_sf['pop_pad_homem'] = df_sf['pop_pad_homem'].astype('uint64')
df_sf['pop_mulher'] = df_sf['pop_mulher'].astype('uint64')
df_sf['pop_pad_mulher'] = df_sf['pop_pad_mulher'].astype('uint64')
df_sf['mes'] = df_sf['mes'].astype('uint8')
df_sf['notificacoes_total'] = df_sf['notificacoes_total'].astype('uint32')
df_sf['notificacoes_homem'] = df_sf['notificacoes_homem'].astype('uint32')
df_sf['notificacoes_mulher'] = df_sf['notificacoes_mulher'].astype('uint32')
df_sf['taxa_notific_total'] = df_sf['taxa_notific_total'].astype('float32')
df_sf['taxa_notific_homem'] = df_sf['taxa_notific_homem'].astype('float32')
df_sf['taxa_notific_mulher'] = df_sf['taxa_notific_mulher'].astype('float32')
df_sf['grupo'] = df_sf['grupo'].astype('uint8')

#df_sf.to_hdf('taxa_sih.h5', "df_sf")

df_sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117600 entries, 0 to 117599
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   municipio            117600 non-null  object
#  1   id_municipio         117600 non-null  uint32
#  2   ano                  117600 non-null  uint16
#  3   mes                  117600 non-null  uint8
#  4   agravo               117600 non-null  object
#  5   grupo                117600 non-null  uint8
#  6   pop_total            117600 non-null  uint64
#  7   pop_pad_total        117600 non-null  uint64
#  8   pop_homem            117600 non-null  uint64
#  9   pop_pad_homem        117600 non-null  uint64
#  10  pop_mulher           117600 non-null  uint64
#  11  pop_pad_mulher       117600 non-null  uint64
#  12  notificacoes_total   117600 non-null  uint32
#  13  notificacoes_homem   117600 non-null  uint32
#  14  notificacoes_mulher  117600 non-null  uint32
# ...
