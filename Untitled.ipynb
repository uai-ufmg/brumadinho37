# %%
import pandas as pd
import numpy as np
import os

from itertools import product

# %%
df = pd.read_csv("taxa_sim.csv", encoding='utf-8', sep=',')

# %%
df
# Out:
#            municipio  id_municipio   ano faixa_etaria  pop_total  \
# 0             Abaeté        310020  2010          0a4       1377
# 1             Abaeté        310020  2010          0a4       1377
# 2             Abaeté        310020  2010          0a4       1377
# 3             Abaeté        310020  2010          0a4       1377
# 4             Abaeté        310020  2010          0a4       1377
# ...              ...           ...   ...          ...        ...
# 12851995  Vespasiano        317120  2019     >=80anos       1507
# 12851996  Vespasiano        317120  2019     >=80anos       1507
# 12851997  Vespasiano        317120  2019     >=80anos       1507
# 12851998  Vespasiano        317120  2019     >=80anos       1507
# 12851999  Vespasiano        317120  2019     >=80anos       1507
#
#           pop_pad_total  pop_homem  pop_pad_homem  pop_mulher  pop_pad_mulher  \
# 0               1338553        702         684629         675          653924
# ...
